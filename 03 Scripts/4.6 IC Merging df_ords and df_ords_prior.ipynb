# %% [markdown]
# # 4.6 Combining & Exporting Data

# %% [markdown]
# ### This script contains the following points:
#
# #### 1. Import Data
# #### 2. Check Output of Data (fixing removal of column eval_set)
# #### 3. Merge df_ords and df_ords_prior

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 1. Import Data

# %%
# Importing data
path = r'/Users/andrewruhnow/Documents/12-2023 Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/andrewruhnow/Documents/12-2023 Instacart Basket Analysis'

# %%
# Importing orders_products_prior.csv
df_ords_prior = pd.read_csv(r'/Users/andrewruhnow/Documents/12-2023 Instacart Basket Analysis/02 Data/Original Data/orders_products_prior.csv', index_col = False)

# %%
# Importing latest orders_checked_1.csv from prepared data folder
df_ords = pd.read_csv(r'/Users/andrewruhnow/Documents/12-2023 Instacart Basket Analysis/02 Data/Prepared Data/orders_checked_1.csv', index_col = False)

# %%
# Importing latest products_checked_1csv from prepared data folder
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked_1.csv'), index_col = False)

# %% [markdown]
# ## 2. Check Output of Data (fixing removal of column eval_set)

# %%
# Check the output of df_ord
df_ords.head ()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             1           1   2398795        1    prior             2
# 2             2           2    473747        1    prior             3
# 3             3           3   2254736        1    prior             4
# 4             4           4    431534        1    prior             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  first_order
# 0                   2                  8                     NaN         True
# 1                   3                  7                    15.0        False
# 2                   3                 12                    21.0        False
# 3                   4                  7                    29.0        False
# 4                   4                 15                    28.0        False

# %%
df_ords.describe()
# Out:
#        Unnamed: 0.1    Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# ...

# %%
df_ords.shape
# Out:
# (3421083, 10)

# %%
# Check the output of df_prods
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods.describe()
# Out:
#        Unnamed: 0    product_id      aisle_id  department_id        prices
# count  49693.0000  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24846.0000  24844.345139     67.770249      11.728433      9.994136
# std    14345.2778  14343.717401     38.316774       5.850282    453.519686
# min        0.0000      1.000000      1.000000       1.000000      1.000000
# 25%    12423.0000  12423.000000     35.000000       7.000000      4.100000
# 50%    24846.0000  24845.000000     69.000000      13.000000      7.100000
# 75%    37269.0000  37265.000000    100.000000      17.000000     11.200000
# max    49692.0000  49688.000000    134.000000      21.000000  99999.000000

# %%
df_prods.shape
# Out:
# (49693, 6)

# %%
# Check output of df_ords_prior
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords_prior.describe()
# Out:
#            order_id    product_id  add_to_cart_order     reordered
# count  3.243449e+07  3.243449e+07       3.243449e+07  3.243449e+07
# mean   1.710749e+06  2.557634e+04       8.351076e+00  5.896975e-01
# std    9.873007e+05  1.409669e+04       7.126671e+00  4.918886e-01
# min    2.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.559430e+05  1.353000e+04       3.000000e+00  0.000000e+00
# 50%    1.711048e+06  2.525600e+04       6.000000e+00  1.000000e+00
# 75%    2.565514e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421083e+06  4.968800e+04       1.450000e+02  1.000000e+00

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
# Dropping eval_set column from orders.csv
df_ords.drop(columns = ['eval_set'], inplace = True)

# %%
df_ords.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  first_order
# 0                   2                  8                     NaN         True
# 1                   3                  7                    15.0        False
# 2                   3                 12                    21.0        False
# 3                   4                  7                    29.0        False
# 4                   4                 15                    28.0        False

# %% [markdown]
# ## 3. Merge df_ords and df_ords_prior

# %%
# Merging new data frame with df_ords
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
# Checking output
df_merged_large.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  first_order  \
# 0                   2                  8                     NaN         True
# 1                   2                  8                     NaN         True
# 2                   2                  8                     NaN         True
# 3                   2                  8                     NaN         True
# 4                   2                  8                     NaN         True
#
#    product_id  add_to_cart_order  reordered _merge
# 0         196                  1          0   both
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Export data to pkl
df_merged_large.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))
